# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.pyplot import *
from IPython.display import display
# %matplotlib inline
 
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png','pdf')

# %%
agg_data = pd.read_csv('../data/brands_500.csv')
agg_data = agg_data[agg_data['_unit_state'] != 'canceled']
agg_no_test = agg_data[agg_data['_golden'] == False]


#full_data = pd.read_csv('full_report.csv')

# %% [markdown]
# ### Confidence

# %% [markdown]
# #### With Test Questions

# %%
agg_data[['label:confidence']].describe()
# Out:
#        label:confidence
# count        636.000000
# mean           0.832526
# std            0.185574
# min            0.335800
# 25%            0.669250
# 50%            0.922150
# 75%            1.000000
# max            1.000000

# %%
color_map = plt.cm.get_cmap('tab10')
#plt.title('Confidence of Labeling')
plt.grid(axis='y', linestyle='dashed')
ticks = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1]
plt.xticks(ticks)
n, bins, patches = plt.hist(
    agg_data['label:confidence'], bins=ticks, color='green')
bin_centers = 0.5 * (bins[:-1] + bins[1:])

# scale values to interval [0,1]
col = bin_centers - min(bin_centers)
col /= max(col)

for c, p in zip(col, patches):
    plt.setp(p, 'facecolor', color_map(c))
plt.show()

# %% [markdown]
# #### Without Test Questions

# %%
agg_no_test[['label:confidence']].describe()
# Out:
#        label:confidence
# count        507.000000
# mean           0.833535
# std            0.190735
# min            0.335800
# 25%            0.665550
# 50%            1.000000
# 75%            1.000000
# max            1.000000

# %%
color_map = plt.cm.get_cmap('tab10')
#plt.title('Confidence of Labeling')
plt.grid(axis='y', linestyle='dashed')
ticks = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1]
plt.xticks(ticks)
n, bins, patches = plt.hist(
    agg_no_test['label:confidence'], bins=ticks, color='green')
bin_centers = 0.5 * (bins[:-1] + bins[1:])

# scale values to interval [0,1]
col = bin_centers - min(bin_centers)
col /= max(col)

for c, p in zip(col, patches):
    plt.setp(p, 'facecolor', color_map(c))
plt.show()

# %% [markdown]
# #### Least confident sentences

# %%
color_map = sns.light_palette('blue', as_cmap=True)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.expand_frame_repr', True)

lc = agg_no_test[['id', 'label:confidence', 'label']]
lc = lc.sort_values('label:confidence')
lc07 = (lc[lc['label:confidence'] <= 0.7])
lc06 = (lc[lc['label:confidence'] <= 0.6])
print('Confidence <= 0.7')
display(lc07.describe())
print('Confidence <= 0.6')
display(lc06.describe())
# Out:
# Confidence <= 0.7
#        label:confidence
# count  192.000000
# mean   0.622719
# std    0.097740
# min    0.335800
# 25%    0.634100
# 50%    0.652400
# 75%    0.675875
# max    0.700000
# Confidence <= 0.6
#        label:confidence
# count  29.000000
# mean   0.409162
# std    0.083407
# min    0.335800
# 25%    0.349500
# 50%    0.378900
# 75%    0.463700
# max    0.583300

# %%
merged = pd.merge(lc, sentences_p, on=['_unit_id'], how='inner', suffixes=['_l', '_r'])
merged.rename(columns={'assigned_class_l' : 'assigned', 'assigned_class_r':'proposed'}, inplace=True)
merged[['assigned_class:confidence', 'assigned', '_trust', 'proposed', 'new_sentence']].style.background_gradient(cmap=color_map,subset=['assigned_class:confidence'])
#sentences_p.style.background_gradient(cmap=color_map,subset=['_trust'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-339e29b1c1f7> in <module>()
# ----> 1 sentences = full_data[full_data['_unit_id'].isin(lc['_unit_id'].tolist())]
#       2 sentences_p = sentences[['id','label', '_trust', 'text_raw']]
#       3 #sentences_p.style.background_gradient(cmap=color_map,subset=['_trust'])
#
# NameError: name 'full_data' is not defined

# %%
merged = pd.merge(lc, sentences_p, on=['_unit_id'], how='inner', suffixes=['_l', '_r'])
merged.rename(columns={'assigned_class_l' : 'assigned', 'assigned_class_r':'proposed'}, inplace=True)
merged[['assigned_class:confidence', 'assigned', '_trust', 'proposed', 'new_sentence']].style.background_gradient(cmap=color_map,subset=['assigned_class:confidence'])
# Out:
# <style  type="text/css" >
#     #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow0_col0 {
#             background-color:  #e5e5ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow1_col0 {
#             background-color:  #e5e5ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow2_col0 {
#             background-color:  #e5e5ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow3_col0 {
#             background-color:  #e4e4ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow4_col0 {
#             background-color:  #e4e4ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow5_col0 {
#             background-color:  #e4e4ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow6_col0 {
#             background-color:  #d8d8ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow7_col0 {
#             background-color:  #d8d8ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow8_col0 {
#             background-color:  #d8d8ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow9_col0 {
#             background-color:  #5e5eff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow10_col0 {
#             background-color:  #5e5eff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow11_col0 {
#             background-color:  #5e5eff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow12_col0 {
#             background-color:  #5e5eff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow13_col0 {
#             background-color:  #5e5eff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow14_col0 {
#             background-color:  #5e5eff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow15_col0 {
#             background-color:  #5e5eff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow16_col0 {
#             background-color:  #5e5eff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow17_col0 {
#             background-color:  #5e5eff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow18_col0 {
#             background-color:  #5e5eff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow19_col0 {
#             background-color:  #5b5bff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow20_col0 {
#             background-color:  #5b5bff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow21_col0 {
#             background-color:  #5b5bff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow22_col0 {
#             background-color:  #5b5bff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow23_col0 {
#             background-color:  #5858ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow24_col0 {
#             background-color:  #5858ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow25_col0 {
#             background-color:  #5858ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow26_col0 {
#             background-color:  #5858ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow27_col0 {
#             background-color:  #5757ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow28_col0 {
#             background-color:  #5757ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow29_col0 {
#             background-color:  #5757ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow30_col0 {
#             background-color:  #5757ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow31_col0 {
#             background-color:  #5656ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow32_col0 {
#             background-color:  #5656ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow33_col0 {
#             background-color:  #5656ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow34_col0 {
#             background-color:  #5656ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow35_col0 {
#             background-color:  #5656ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow36_col0 {
#             background-color:  #5656ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow37_col0 {
#             background-color:  #5656ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow38_col0 {
#             background-color:  #5656ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow39_col0 {
#             background-color:  #5656ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow40_col0 {
#             background-color:  #5656ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow41_col0 {
#             background-color:  #5656ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow42_col0 {
#             background-color:  #5656ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow43_col0 {
#             background-color:  #4646ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow44_col0 {
#             background-color:  #4646ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow45_col0 {
#             background-color:  #4646ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow46_col0 {
#             background-color:  #4646ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow47_col0 {
#             background-color:  #4646ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow48_col0 {
#             background-color:  #4646ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow49_col0 {
#             background-color:  #4646ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow50_col0 {
#             background-color:  #4646ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow51_col0 {
#             background-color:  #4141ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow52_col0 {
#             background-color:  #4141ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow53_col0 {
#             background-color:  #4141ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow54_col0 {
#             background-color:  #4141ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow55_col0 {
#             background-color:  #4040ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow56_col0 {
#             background-color:  #4040ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow57_col0 {
#             background-color:  #4040ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow58_col0 {
#             background-color:  #4040ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow59_col0 {
#             background-color:  #2626ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow60_col0 {
#             background-color:  #2626ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow61_col0 {
#             background-color:  #2626ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow62_col0 {
#             background-color:  #2626ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow63_col0 {
#             background-color:  #2626ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow64_col0 {
#             background-color:  #2626ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow65_col0 {
#             background-color:  #2626ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow66_col0 {
#             background-color:  #2626ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow67_col0 {
#             background-color:  #2626ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow68_col0 {
#             background-color:  #1010ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow69_col0 {
#             background-color:  #1010ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow70_col0 {
#             background-color:  #1010ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow71_col0 {
#             background-color:  #1010ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow72_col0 {
#             background-color:  #1010ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow73_col0 {
#             background-color:  #1010ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow74_col0 {
#             background-color:  #1010ff;
#         }    #T_1bec747a_c7c9_11e7_aa8e_80e65026acccrow75_col0 {
#             background-color:  #1010ff;
#         }

# %% [markdown]
# ### Labels

# %% [markdown]
# #### Distribution

# %%
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct


labels = agg_no_test['label']
plt.figure(figsize=plt.figaspect(1))
plt.pie(
    labels.value_counts().values,
    labels=labels.value_counts().keys().tolist(),
    radius=2,
    autopct=make_autopct(labels.value_counts().values))
plt.show()
